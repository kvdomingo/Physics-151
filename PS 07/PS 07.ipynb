# %%
import numpy as np
import matplotlib.pyplot as mp
import scipy.stats as stat
import numpy.random as rd
from jupyterthemes import jtplot

# %%
jtplot.reset()
mp.rcParams["figure.figsize"] = (3*16/9, 3)
mp.rcParams["figure.dpi"] = 100
mp.rcParams["font.family"] = "serif"
mp.rcParams["text.usetex"] = True

# %%
def p(x, a, gamma):
    return 1/np.pi * gamma/((x-a)**2 + gamma**2)

def g(x):
    return 1/np.sqrt(2*np.pi) * np.exp(-x**2/2)

x = np.linspace(-10, 10, 500)
a = 0
gamma = 1

# %%
mp.plot(x, p(x, a, gamma), "k-", label="Lorentz")
mp.plot(x, g(x), "r-", label="Gaussian")
mp.xlabel("$x$")
mp.ylabel("$p(x)$")
mp.legend()
mp.grid()
mp.savefig("lorentz.png", dpi=300, bbox_inches="tight")
mp.show()

# %%
def p(S, Smean, sigma):
    return 1/np.sqrt(2*np.pi*sigma**2) * np.exp(-(S - Smean)**2/2/sigma**2)

Sbar = lambda N, sbar: N*sbar
sigmassq = lambda N, sigma: N*sigma**2
